# %% [markdown]
# ## Ecuaciones Diferenciales Ordinarias con Condiciones Iniciales
#
# ### Puntos generales
#
# - Las ecuaciones diferenciales
# - Diagrana de fase
# - Condiciones iniciales
# - Ejemplos: Clima, multivariables
# - Metodos para resolver EDO cond. iniciales
# - Aplicación en un caso
# - Caos
# - Programa y plot

# %%
# Ecuacion diferencial ordinal
def edo():
    return None

# %%
# Condiciones iniciales
a = 0
b = 0
c = 0

# %%
# Clima y diagrama de fase
# Atractores
